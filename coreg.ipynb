# %%
import os
import mne
import numpy as np

directory = '/data/users2/nshor/Multiband_with_MEG/sub-02/meg/'
subjects_dir = '/data/users2/mjafarlou1/freesurfer/subs/'
subject = 'sub-02'

# create a head model for the subject
#mne.bem.make_watershed_bem(subject, subjects_dir=subjects_dir, overwrite=True)

# iterate over all fif files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.fif'):
        # read the fif file
        path = os.path.join(directory, filename)
        info = mne.io.read_info(path)

        # create Coregistration object and fit fiducials
        coreg = mne.coreg.Coregistration(info, subject, subjects_dir, fiducials="estimated")
        coreg.fit_fiducials(verbose=True)

        # omit head shape points and fit ICP
        coreg.omit_head_shape_points(distance=5. / 1000)  # distance is in meters
        coreg.fit_icp(n_iterations=20, nasion_weight=10., verbose=True)

        # compute and print distances
        dists = coreg.compute_dig_mri_distances() * 1e3  # in mm
        print(f"Distance between HSP and MRI (mean/min/max):\n{np.mean(dists):.2f} mm "
              f"/ {np.min(dists):.2f} mm / {np.max(dists):.2f} mm")

        # write trans file
        mne.write_trans(f'/data/users2/mjafarlou1/results/coregistration/{filename[:-4]}-trans.fif', coreg.trans)
# Out:
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.80 mm
# End   median distance:   6.62 mm
# Coregistration: Excluding 79 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.13 mm
#   ICP  1  median distance:   2.93 mm
#   ICP  2  median distance:   2.89 mm
#   ICP  3  median distance:   2.93 mm
#   ICP  4  median distance:   2.72 mm
#   ICP  5  median distance:   2.64 mm
#   ICP  6  median distance:   2.58 mm
#   ICP  7  median distance:   2.55 mm
# End       median distance:   2.55 mm
# Distance between HSP and MRI (mean/min/max):
# 3.19 mm / 0.60 mm / 16.90 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.45 mm
# End   median distance:   6.36 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.99 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.67 mm
#   ICP  3  median distance:   2.61 mm
#   ICP  4  median distance:   2.61 mm
#   ICP  5  median distance:   2.55 mm
#   ICP  6  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 3.02 mm / 0.64 mm / 13.94 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  16.01 mm
# End   median distance:   7.12 mm
# Coregistration: Excluding 86 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.92 mm
#   ICP  1  median distance:   2.79 mm
#   ICP  2  median distance:   2.60 mm
#   ICP  3  median distance:   2.55 mm
#   ICP  4  median distance:   2.42 mm
#   ICP  5  median distance:   2.35 mm
#   ICP  6  median distance:   2.22 mm
#   ICP  7  median distance:   2.25 mm
#   ICP  8  median distance:   2.22 mm
# End       median distance:   2.22 mm
# Distance between HSP and MRI (mean/min/max):
# 3.00 mm / 0.32 mm / 16.32 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  14.49 mm
# End   median distance:   6.19 mm
# Coregistration: Excluding 70 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   2.83 mm
#   ICP  1  median distance:   2.81 mm
#   ICP  2  median distance:   2.71 mm
#   ICP  3  median distance:   2.60 mm
#   ICP  4  median distance:   2.59 mm
#   ICP  5  median distance:   2.67 mm
#   ICP  6  median distance:   2.60 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.52 mm
# End       median distance:   2.52 mm
# Distance between HSP and MRI (mean/min/max):
# 2.98 mm / 0.52 mm / 14.36 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.14 mm
# End   median distance:   6.60 mm
# Coregistration: Excluding 85 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.06 mm
#   ICP  1  median distance:   2.78 mm
#   ICP  2  median distance:   2.80 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.77 mm
#   ICP  5  median distance:   2.71 mm
#   ICP  6  median distance:   2.59 mm
#   ICP  7  median distance:   2.54 mm
# End       median distance:   2.54 mm
# Distance between HSP and MRI (mean/min/max):
# 2.99 mm / 0.38 mm / 15.42 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
#     Triangle neighbors and vertex normals...
# Using low resolution head model in /data/users2/mjafarlou1/freesurfer/subs/sub-02/bem/outer_skin.surf
#     Triangle neighbors and vertex normals...
# Estimating fiducials from fsaverage.
# Aligning using fiducials
# Start median distance:  15.20 mm
# End   median distance:   6.92 mm
# Coregistration: Excluding 82 head shape points with distance >= 0.005 m.
# Aligning using ICP
# Start     median distance:   3.08 mm
#   ICP  1  median distance:   3.03 mm
#   ICP  2  median distance:   2.86 mm
#   ICP  3  median distance:   2.81 mm
#   ICP  4  median distance:   2.80 mm
#   ICP  5  median distance:   2.76 mm
#   ICP  6  median distance:   2.65 mm
#   ICP  7  median distance:   2.55 mm
#   ICP  8  median distance:   2.44 mm
#   ICP  9  median distance:   2.44 mm
#   ICP 10  median distance:   2.58 mm
#   ICP 11  median distance:   2.63 mm
# End       median distance:   2.63 mm
# Distance between HSP and MRI (mean/min/max):
# 2.93 mm / 0.45 mm / 14.76 mm
